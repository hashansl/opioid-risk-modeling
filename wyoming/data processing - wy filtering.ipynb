# %% [markdown]
# #### Filtering US dataframe into WY

# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np
import itertools
from itertools import combinations
from scipy import spatial
import pickle as pickle
import gudhi
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
import seaborn as sns
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from matplotlib import pyplot
import warnings

# Ignore FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# /Users/h6x/anaconda3/envs/TDA/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# imoporting SVI data for the entire US(county level) 
us_svi = gpd.read_file('../data/processed data/SVI 2020 with HepVu/SVI2020_US_county_with_opioid_indicators.shp')

# %%
# include only the Wyoming(county level)
filtered_svi_df = us_svi[us_svi['ST_ABBR'].isin(['WY'])]

# %%
# reset index
filtered_svi_df.reset_index(drop=True, inplace=True)

# %%
filtered_svi_df
# Out:
#     ST    STATE ST_ABBR STCNTY       COUNTY   FIPS  \
# 0   56  Wyoming      WY  56001       Albany  56001
# 1   56  Wyoming      WY  56003     Big Horn  56003
# 2   56  Wyoming      WY  56005     Campbell  56005
# 3   56  Wyoming      WY  56007       Carbon  56007
# 4   56  Wyoming      WY  56009     Converse  56009
# 5   56  Wyoming      WY  56011        Crook  56011
# 6   56  Wyoming      WY  56013      Fremont  56013
# 7   56  Wyoming      WY  56015       Goshen  56015
# 8   56  Wyoming      WY  56017  Hot Springs  56017
# 9   56  Wyoming      WY  56019      Johnson  56019
# 10  56  Wyoming      WY  56021      Laramie  56021
# 11  56  Wyoming      WY  56023      Lincoln  56023
# 12  56  Wyoming      WY  56025      Natrona  56025
# 13  56  Wyoming      WY  56027     Niobrara  56027
# 14  56  Wyoming      WY  56029         Park  56029
# 15  56  Wyoming      WY  56031       Platte  56031
# 16  56  Wyoming      WY  56033     Sheridan  56033
# 17  56  Wyoming      WY  56035     Sublette  56035
# 18  56  Wyoming      WY  56037   Sweetwater  56037
# 19  56  Wyoming      WY  56039        Teton  56039
# 20  56  Wyoming      WY  56041        Uinta  56041
# 21  56  Wyoming      WY  56043     Washakie  56043
# 22  56  Wyoming      WY  56045       Weston  56045
#
#                        LOCATION     AREA_SQMI  E_TOTPOP  M_TOTPOP  ...  \
# 0        Albany County, Wyoming   4274.325006     38664         0  ...
# 1      Big Horn County, Wyoming   3136.955873     11809         0  ...
# 2      Campbell County, Wyoming   4802.063272     46958         0  ...
# 3        Carbon County, Wyoming   7897.799466     15073         0  ...
# 4      Converse County, Wyoming   4254.992932     13842         0  ...
# 5         Crook County, Wyoming   2854.478701      7502         0  ...
# 6       Fremont County, Wyoming   9183.586200     39711         0  ...
# 7        Goshen County, Wyoming   2225.611986     13301         0  ...
# 8   Hot Springs County, Wyoming   2004.430582      4550         0  ...
# 9       Johnson County, Wyoming   4154.150221      8518         0  ...
# 10      Laramie County, Wyoming   2685.862593     99272         0  ...
# 11      Lincoln County, Wyoming   4075.335109     19640         0  ...
# 12      Natrona County, Wyoming   5340.535196     80067         0  ...
# 13     Niobrara County, Wyoming   2626.026681      2377         0  ...
# 14         Park County, Wyoming   6939.035846     29273         0  ...
# 15       Platte County, Wyoming   2081.457973      8572         0  ...
# 16     Sheridan County, Wyoming   2523.359998     30397         0  ...
# 17     Sublette County, Wyoming   4886.479510      9865         0  ...
# 18   Sweetwater County, Wyoming  10426.975770     43352         0  ...
# 19        Teton County, Wyoming   3996.846846     23356         0  ...
# 20        Uinta County, Wyoming   2081.719808     20374         0  ...
# 21     Washakie County, Wyoming   2238.678265      7933         0  ...
# 22       Weston County, Wyoming   2398.003892      6942         0  ...
#
#     MP_NHPI  EP_TWOMORE  MP_TWOMORE  EP_OTHERRA  MP_OTHERRA  Shape_Leng  \
# 0       0.1         3.2         0.9         0.1         0.1    5.381414
# 1       0.2         1.7         0.7         0.1         0.2    4.750094
# 2       0.1         2.7         0.6         0.0         0.1    4.934223
# 3       0.1         1.4         0.6         0.1         0.1    6.628132
# 4       0.3         2.9         0.3         0.0         0.3    4.927427
# 5       0.5         2.2         1.1         0.0         0.5    3.702220
# 6       0.1         2.9         0.4         0.0         0.1    9.152019
# 7       0.1         1.4         0.4         0.8         0.8    3.295879
# 8       0.8         1.2         0.7         1.1         1.1    4.655413
# 9       0.4         0.8         0.5         0.0         0.4    4.956049
# 10      0.1         3.2         0.5         0.1         0.1    3.763161
# 11      0.2         2.7         0.5         0.0         0.2    5.563516
# 12      0.1         2.2         0.4         0.0         0.1    5.161606
# 13      2.2         2.3         3.0         0.0         1.5    3.472476
# 14      0.1         1.8         0.4         0.4         0.3    8.013402
# 15      0.7         4.4         2.7         0.0         0.4    3.178152
# 16      0.1         1.5         0.6         0.2         0.2    4.727247
# 17      0.4         3.7         1.0         0.0         0.4    5.638501
# 18      0.1         2.2         0.8         0.2         0.3    7.660062
# 19      0.1         1.0         0.6         0.6         0.8    5.080816
# 20      0.2         2.2         0.4         0.0         0.2    3.158552
# 21      0.4         3.2         0.5         0.4         0.4    4.246732
# 22      2.0         2.9         1.9         0.0         0.5    3.407164
#
#     Shape_Area  GEO ID  NOD_Rate  \
# 0     1.206409   56001      16.1
# 1     0.926044   56003      21.4
# 2     1.403033   56005      18.2
# 3     2.230716   56007      34.1
# 4     1.218659   56009      17.1
# 5     0.841022   56011      11.7
# 6     2.651021   56013      26.2
# 7     0.629026   56015      14.1
# 8     0.580314   56017      24.5
# 9     1.213930   56019      17.4
# 10    0.748506   56021      20.2
# 11    1.156991   56023      22.9
# 12    1.536504   56025      22.8
# 13    0.752215   56027      16.5
# 14    2.042042   56029      17.8
# 15    0.595277   56031      18.8
# 16    0.744136   56033      12.5
# 17    1.405675   56035      13.1
# 18    2.937306   56037      31.9
# 19    1.224489   56039      11.2
# 20    0.581250   56041      30.0
# 21    0.650686   56043      21.3
# 22    0.695465   56045      13.7
#
#                                              geometry
# 0   POLYGON ((-106.32274 41.21722, -106.32269 41.3...
# 1   POLYGON ((-108.62184 44.99613, -108.62182 44.9...
# 2   POLYGON ((-106.02524 44.97958, -106.02491 44.9...
# 3   POLYGON ((-107.92977 41.65419, -107.92974 41.6...
# 4   POLYGON ((-106.07807 43.49447, -106.01737 43.4...
# 5   POLYGON ((-105.08539 44.61413, -105.08535 44.6...
# 6   POLYGON ((-110.05318 44.00802, -110.05037 44.0...
# 7   POLYGON ((-104.65564 42.60947, -104.62551 42.6...
# 8   POLYGON ((-109.31295 43.81329, -109.27259 43.8...
# 9   POLYGON ((-107.36968 44.55834, -107.36962 44.5...
# 10  POLYGON ((-105.28020 41.39538, -105.27760 41.3...
# 11  POLYGON ((-111.04711 42.14897, -111.04706 42.1...
# 12  POLYGON ((-107.54353 42.78136, -107.50142 42.7...
# 13  POLYGON ((-104.89994 43.49964, -104.75052 43.5...
# 14  POLYGON ((-111.05456 45.00096, -111.04507 45.0...
# 15  POLYGON ((-105.28651 42.60583, -105.25054 42.6...
# 16  POLYGON ((-107.91152 45.00067, -107.90818 45.0...
# 17  POLYGON ((-110.62343 42.77921, -110.58766 42.7...
# 18  POLYGON ((-110.05438 42.01103, -110.05436 42.0...
# 19  POLYGON ((-111.05361 44.66627, -110.75076 44.6...
# 20  POLYGON ((-111.04662 41.15604, -111.04659 41.2...
# 21  POLYGON ((-108.55063 44.15179, -108.55056 44.1...
# 22  POLYGON ((-105.08078 43.96622, -105.07928 44.1...
#
# [23 rows x 163 columns]

# %%
# Plot the data for the Washington DC, Virginia, Maryland, and West Virginia(county level)
ax = filtered_svi_df.plot(figsize=(10, 10), column="NOD_Rate", legend=False, cmap='OrRd', edgecolor='black',linewidth=0.3)

for idx, row in filtered_svi_df.iterrows():
    centroid = row.geometry.centroid
    county_name = row.FIPS
    ax.annotate(text=county_name, xy=(centroid.x, centroid.y), ha='center', fontsize=0.5)

# Display the plot
plt.show()

# %% [markdown]
# #### Saving dataframe to a shapefile

# %%
# Convert the DataFrame to a GeoDataFrame
gdf = gpd.GeoDataFrame(filtered_svi_df, geometry='geometry')

# %%
# Save the GeoDataFrame to a Shapefile
gdf.to_file("./data/processed data/SVI2020 WY counties with death rate HepVu/SVI2020_WY_counties_with_death_rate_HepVu.shp", driver='ESRI Shapefile')
