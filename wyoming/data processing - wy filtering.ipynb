# %% [markdown]
# #### SVI data and death data processing - TN

# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np
import itertools
from itertools import combinations
from scipy import spatial
import pickle as pickle
import gudhi
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
import seaborn as sns
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from matplotlib import pyplot
import warnings

# Ignore FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# imoporting SVI data for the entire US(county level) 
us_svi = gpd.read_file('../data/processed data/SVI 2018 with HepVu/SVI2018_US_county_with_opioid_indicators.shp')

# %%
# include only the Wyoming(county level)
filtered_svi_df = us_svi[us_svi['ST_ABBR'].isin(['WY'])]

# %%
# reset index
filtered_svi_df.reset_index(drop=True, inplace=True)

# %%
filtered_svi_df
# Out:
#     ST    STATE ST_ABBR       COUNTY   FIPS                     LOCATION  \
# 0   56  WYOMING      WY     Big Horn  56003     Big Horn County, Wyoming
# 1   56  WYOMING      WY       Carbon  56007       Carbon County, Wyoming
# 2   56  WYOMING      WY     Converse  56009     Converse County, Wyoming
# 3   56  WYOMING      WY        Crook  56011        Crook County, Wyoming
# 4   56  WYOMING      WY      Fremont  56013      Fremont County, Wyoming
# 5   56  WYOMING      WY       Goshen  56015       Goshen County, Wyoming
# 6   56  WYOMING      WY      Johnson  56019      Johnson County, Wyoming
# 7   56  WYOMING      WY      Laramie  56021      Laramie County, Wyoming
# 8   56  WYOMING      WY      Natrona  56025      Natrona County, Wyoming
# 9   56  WYOMING      WY         Park  56029         Park County, Wyoming
# 10  56  WYOMING      WY       Platte  56031       Platte County, Wyoming
# 11  56  WYOMING      WY     Sheridan  56033     Sheridan County, Wyoming
# 12  56  WYOMING      WY     Sublette  56035     Sublette County, Wyoming
# 13  56  WYOMING      WY     Washakie  56043     Washakie County, Wyoming
# 14  56  WYOMING      WY       Weston  56045       Weston County, Wyoming
# 15  56  WYOMING      WY       Albany  56001       Albany County, Wyoming
# 16  56  WYOMING      WY     Campbell  56005     Campbell County, Wyoming
# 17  56  WYOMING      WY  Hot Springs  56017  Hot Springs County, Wyoming
# 18  56  WYOMING      WY      Lincoln  56023      Lincoln County, Wyoming
# 19  56  WYOMING      WY     Niobrara  56027     Niobrara County, Wyoming
# 20  56  WYOMING      WY   Sweetwater  56037   Sweetwater County, Wyoming
# 21  56  WYOMING      WY        Uinta  56041        Uinta County, Wyoming
# 22  56  WYOMING      WY        Teton  56039        Teton County, Wyoming
#
#        AREA_SQMI  E_TOTPOP  M_TOTPOP   E_HU  ...  F_THEME4  F_TOTAL  \
# 0    3136.955875     11901         0   5461  ...         0        0
# 1    7897.799409     15477         0   8755  ...         0        0
# 2    4254.961401     13997         0   6654  ...         0        0
# 3    2854.478707      7410         0   3650  ...         0        0
# 4    9183.586196     40076         0  17983  ...         0        0
# 5    2225.612167     13438         0   6031  ...         0        0
# 6    4154.150213      8515         0   4618  ...         0        0
# 7    2685.862565     97692         0  42922  ...         0        0
# 8    5340.522413     80610         0  36703  ...         0        0
# 9    6939.035837     29121         0  14324  ...         0        0
# 10   2081.447555      8673         0   4822  ...         0        0
# 11   2523.360011     30012         0  14779  ...         0        0
# 12   4886.479501      9951         0   5989  ...         0        0
# 13   2238.672972      8129         0   3868  ...         0        0
# 14   2398.003891      7100         0   3565  ...         0        0
# 15   4274.325013     38102         0  19162  ...         1        1
# 16   4802.063270     47708         0  20158  ...         0        1
# 17   2004.428189      4680         0   2565  ...         0        1
# 18   4075.335083     19011         0   9319  ...         0        1
# 19   2626.026681      2448         0   1377  ...         1        1
# 20  10426.975725     44117         0  19628  ...         0        1
# 21   2081.719807     20609         0   8972  ...         0        1
# 22   3996.844622     23059         0  13680  ...         1        2
#
#     E_UNINSUR  M_UNINSUR  EP_UNINSUR  MP_UNINSUR  E_DAYPOP  GEO ID  NOD_Rate  \
# 0        1843        302        15.8         2.6     11468   56003      18.5
# 1        1519        312        10.3         2.1     13963   56007      20.9
# 2        1180        310         8.5         2.2     12080   56009      11.8
# 3         741        153        10.1         2.1      5896   56011       8.9
# 4        7116        563        18.0         1.4     35762   56013      21.8
# 5        1610        395        12.3         3.0     11536   56015      11.5
# 6        1161        354        13.8         4.2      7778   56019      12.5
# 7        7859        919         8.3         1.0     96000   56021      13.8
# 8       10684        983        13.5         1.2     80758   56025      18.3
# 9        3473        691        12.0         2.4     28312   56029      13.5
# 10        861        256        10.0         3.0      7922   56031      16.3
# 11       2864        529         9.7         1.8     30230   56033      11.0
# 12       1330        459        13.4         4.6      9573   56035      11.3
# 13       1223        245        15.4         3.1      7859   56043      19.5
# 14        898        215        13.3         3.2      5576   56045      11.0
# 15       2814        469         7.4         1.2     37423   56001      11.8
# 16       4459        679         9.4         1.4     47727   56005      13.1
# 17        506        147        11.1         3.2      4462   56017      14.5
# 18       2363        404        12.5         2.1     17016   56023      14.8
# 19        339        131        15.8         6.1      2604   56027      11.6
# 20       5240        794        12.0         1.8     45734   56037      18.9
# 21       2499        452        12.2         2.2     19734   56041      19.8
# 22       2305        603        10.0         2.6     29426   56039       9.2
#
#                                              geometry
# 0   POLYGON ((-108.62184 44.99613, -108.62182 44.9...
# 1   POLYGON ((-107.92977 41.65419, -107.92974 41.6...
# 2   POLYGON ((-106.07807 43.49447, -106.01737 43.4...
# 3   POLYGON ((-105.08539 44.61413, -105.08535 44.6...
# 4   POLYGON ((-110.05318 44.00802, -110.05037 44.0...
# 5   POLYGON ((-104.65564 42.60947, -104.62551 42.6...
# 6   POLYGON ((-107.36968 44.55834, -107.36962 44.5...
# 7   POLYGON ((-105.28020 41.39538, -105.27760 41.3...
# 8   POLYGON ((-107.54353 42.78136, -107.50142 42.7...
# 9   POLYGON ((-111.05456 45.00096, -111.04507 45.0...
# 10  POLYGON ((-105.28651 42.60583, -105.25054 42.6...
# 11  POLYGON ((-107.91152 45.00067, -107.90818 45.0...
# 12  POLYGON ((-110.62343 42.77921, -110.58766 42.7...
# 13  POLYGON ((-108.55063 44.15179, -108.55056 44.1...
# 14  POLYGON ((-105.08078 43.96622, -105.07928 44.1...
# 15  POLYGON ((-106.32274 41.21722, -106.32269 41.3...
# 16  POLYGON ((-106.02524 44.97958, -106.02491 44.9...
# 17  POLYGON ((-109.31295 43.81329, -109.27259 43.8...
# 18  POLYGON ((-111.04711 42.14897, -111.04706 42.1...
# 19  POLYGON ((-104.89994 43.49964, -104.75052 43.5...
# 20  POLYGON ((-110.05438 42.01103, -110.05436 42.0...
# 21  POLYGON ((-111.04662 41.15604, -111.04659 41.2...
# 22  POLYGON ((-111.05361 44.66627, -110.75076 44.6...
#
# [23 rows x 126 columns]

# %%
# Plot the data for the Washington DC, Virginia, Maryland, and West Virginia(county level)
ax = filtered_svi_df.plot(figsize=(10, 10), column="NOD_Rate", legend=False, cmap='OrRd', edgecolor='black',linewidth=0.3)

for idx, row in filtered_svi_df.iterrows():
    centroid = row.geometry.centroid
    county_name = row.FIPS
    ax.annotate(text=county_name, xy=(centroid.x, centroid.y), ha='center', fontsize=0.5)

# Display the plot
plt.show()

# %% [markdown]
# #### Saving dataframe to a shapefile

# %%
# Convert the DataFrame to a GeoDataFrame
gdf = gpd.GeoDataFrame(filtered_svi_df, geometry='geometry')

# %%
# Save the GeoDataFrame to a Shapefile
gdf.to_file("./data/processed data/SVI2018 WY counties with death rate HepVu/SVI2018_WY_counties_with_death_rate_HepVu.shp", driver='ESRI Shapefile')
